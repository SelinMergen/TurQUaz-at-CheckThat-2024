# %% [markdown]
# Misc set up

# %%
import os
os.chdir("path-to-your-folder")

# %% [markdown]
# # Making your own attack

# %% [markdown]
# ## Imports

# %%
import gc
import os
import pathlib
import sys
import time
import random
import numpy as np

import OpenAttack
import torch
import datasets
from datasets import Dataset

from OpenAttack.tags import Tag
from OpenAttack.text_process.tokenizer import PunctTokenizer

from metrics.BODEGAScore import BODEGAScore
from utils.data_mappings import dataset_mapping, dataset_mapping_pairs, SEPARATOR_CHAR
from utils.no_ssl_verify import no_ssl_verify
from victims.bert import VictimBERT
from victims.bert import readfromfile_generator as BERT_readfromfile_generator
from victims.bilstm import VictimBiLSTM
from victims.caching import VictimCache
from victims.unk_fix_wrapper import UNK_TEXT

#imports for BodegaAttackEval wrapper
from typing import Any, Dict, Generator, Iterable, List, Optional, Union
from tqdm import tqdm
from OpenAttack.utils import visualizer, result_visualizer, get_language, language_by_name
from OpenAttack.tags import *

# %%
using_mounted_drive = False
print('Cuda device available', torch.cuda.is_available())
# Out:
# Cuda device available True

# %%
import numpy

from datasets import Dataset, DatasetDict, concatenate_datasets
from transformers import AutoTokenizer, DataCollatorWithPadding, AutoConfig
from transformers import AutoModelForSequenceClassification
from torch.utils.data import DataLoader
from tqdm.auto import tqdm

from utils.data_mappings import SEPARATOR
import pathlib

BATCH_SIZE = 16
MAX_LEN = 512
EPOCHS = 5
MAX_BATCHES = -1
pretrained_model = "roberta-base"

def trim(text, tokenizer):
    offsets = tokenizer(text, truncation=True, max_length=MAX_LEN + 10, return_offsets_mapping=True)['offset_mapping']
    limit = len(text)
    if len(offsets) > MAX_LEN:
        limit = offsets[512][1]
    return text[:limit]


def roberta_readfromfile_generator(subset, dir, with_pairs=False, trim_text=False):
    tokenizer = AutoTokenizer.from_pretrained(pretrained_model)
    for line in open(dir / (subset + '.tsv')):
        parts = line.split('\t')
        label = int(parts[0])
        if not with_pairs:
            text = parts[2].strip().replace('\\n', '\n').replace('\\t', '\t').replace('\\\\', '\\')
            if trim_text:
                text = trim(text, tokenizer)
            yield {'fake': label, 'text': text}
        else:
            text1 = parts[2].strip().replace('\\n', '\n').replace('\\t', '\t').replace('\\\\', '\\')
            text2 = parts[3].strip().replace('\\n', '\n').replace('\\t', '\t').replace('\\\\', '\\')
            if trim_text:
                text1 = trim(text1, tokenizer)
                text2 = trim(text2, tokenizer)
            yield {'fake': label, 'text1': text1, 'text2': text2}


def eval_loop(model, eval_dataloader, device, skip_visual=False):
    print("Evaluating...")
    model.eval()
    progress_bar = tqdm(range(len(eval_dataloader)), ascii=True, disable=skip_visual)
    correct = 0
    size = 0
    TPs = 0
    FPs = 0
    FNs = 0
    for i, batch in enumerate(eval_dataloader):
        batch = {k: v.to(device) for k, v in batch.items()}
        with torch.no_grad():
            outputs = model(**batch)

        logits = outputs.logits
        # print(logits)
        # a = input()
        pred = torch.argmax(logits, dim=-1).detach().to(torch.device('cpu')).numpy()
        Y = batch["labels"].to(torch.device('cpu')).numpy()
        eq = numpy.equal(Y, pred)
        size += len(eq)
        correct += sum(eq)
        TPs += sum(numpy.logical_and(numpy.equal(Y, 1.0), numpy.equal(pred, 1.0)))
        FPs += sum(numpy.logical_and(numpy.equal(Y, 0.0), numpy.equal(pred, 1.0)))
        FNs += sum(numpy.logical_and(numpy.equal(Y, 1.0), numpy.equal(pred, 0.0)))
        progress_bar.update(1)

        # print(Y)
        # print(pred)
        # a = input()

        if i == MAX_BATCHES:
            break
    print('Accuracy: ' + str(correct / size))
    print('F1: ' + str(2 * TPs / (2 * TPs + FPs + FNs)))
    print(correct, size, TPs, FPs, FNs)

    results = {
        'Accuracy': correct/size,
        'F1': 2 * TPs / (2 * TPs + FPs + FNs)
    }
    return results


class VictimRoBERTa(OpenAttack.Classifier):
    def __init__(self, path, task, device=torch.device('cpu')):
        self.device = device
        config = AutoConfig.from_pretrained(pretrained_model)
        self.model = AutoModelForSequenceClassification.from_config(config)
        self.model.load_state_dict(torch.load(path))
        self.model.to(device)
        self.model.eval()
        self.tokenizer = AutoTokenizer.from_pretrained(pretrained_model)
        self.with_pairs = (task == 'FC' or task == 'C19')

    def get_pred(self, input_):
        return self.get_prob(input_).argmax(axis=1)

    def get_prob(self, input_):
        try:
            probs = None
            # print(len(input_), input_)

            batched = [input_[i * BATCH_SIZE:(i + 1) * BATCH_SIZE] for i in
                       range((len(input_) + BATCH_SIZE - 1) // BATCH_SIZE)]
            for batched_input in batched:
                if not self.with_pairs:
                    tokenised = self.tokenizer(batched_input, truncation=True, padding=True, max_length=MAX_LEN,
                                               return_tensors="pt")
                else:
                    parts = [x.split(SEPARATOR) for x in batched_input]
                    tokenised = self.tokenizer([x[0] for x in parts], [(x[1] if len(x) == 2 else '') for x in parts],
                                               truncation=True, padding=True,
                                               max_length=MAX_LEN,
                                               return_tensors="pt")
                with torch.no_grad():
                    tokenised = {k: v.to(self.device) for k, v in tokenised.items()}
                    outputs = self.model(**tokenised)
                probs_here = torch.nn.functional.softmax(outputs.logits, dim=-1).to(torch.device('cpu')).numpy()
                if probs is not None:
                    probs = numpy.concatenate((probs, probs_here))
                else:
                    probs = probs_here
            return probs
        except Exception as e:
            # Used for debugging
            raise

# %% [markdown]
# ## (do not change) Wrapper for producing submission file

# %%
class BodegaAttackEval(OpenAttack.AttackEval):
  '''
  wrapper for OpenAttack.AttackEval to produce a submission.tsv file for shared task evaluation

  To perform evaluation, we use a new method: eval_and_save_tsv() rather than the usual AttackEval.eval()
  submission.tsv file consists of 4 columns for each sample in attack set: succeeded, num_queries, original_text and modified text (newlines are escaped)

  '''
  def eval_and_save_tsv(self, dataset: Iterable[Dict[str, Any]], total_len : Optional[int] = None, visualize : bool = False, progress_bar : bool = False, num_workers : int = 0, chunk_size : Optional[int] = None, tsv_file_path: Optional[os.PathLike] = None):
      """
      Evaluation function of `AttackEval`.

      Args:
          dataset: An iterable dataset.
          total_len: Total length of dataset (will be used if dataset doesn't has a `__len__` attribute).
          visualize: Display a pretty result for each data in the dataset.
          progress_bar: Display a progress bar if `True`.
          num_workers: The number of processes running the attack algorithm. Default: 0 (running on the main process).
          chunk_size: Processing pool trunks size.

          tsv_file_path: path to save submission tsv

      Returns:
          A dict of attack evaluation summaries.

      """


      if hasattr(dataset, "__len__"):
          total_len = len(dataset)

      def tqdm_writer(x):
          return tqdm.write(x, end="")

      if progress_bar:
          result_iterator = tqdm(self.ieval(dataset, num_workers, chunk_size), total=total_len)
      else:
          result_iterator = self.ieval(dataset, num_workers, chunk_size)

      total_result = {}
      total_result_cnt = {}
      total_inst = 0
      success_inst = 0

      #list for tsv
      x_orig_list = []
      x_adv_list = []
      num_queries_list = []
      succeed_list = []

      # Begin for
      for i, res in enumerate(result_iterator):
          total_inst += 1
          success_inst += int(res["success"])

          if TAG_Classification in self.victim.TAGS:
              x_orig = res["data"]["x"]
              if res["success"]:
                  x_adv = res["result"]
                  if Tag("get_prob", "victim") in self.victim.TAGS:
                      self.victim.set_context(res["data"], None)
                      try:
                          probs = self.victim.get_prob([x_orig, x_adv])
                      finally:
                          self.victim.clear_context()
                      y_orig = probs[0]
                      y_adv = probs[1]
                  elif Tag("get_pred", "victim") in self.victim.TAGS:
                      self.victim.set_context(res["data"], None)
                      try:
                          preds = self.victim.get_pred([x_orig, x_adv])
                      finally:
                          self.victim.clear_context()
                      y_orig = int(preds[0])
                      y_adv = int(preds[1])
                  else:
                      raise RuntimeError("Invalid victim model")
              else:
                  y_adv = None
                  x_adv = None
                  if Tag("get_prob", "victim") in self.victim.TAGS:
                      self.victim.set_context(res["data"], None)
                      try:
                          probs = self.victim.get_prob([x_orig])
                      finally:
                          self.victim.clear_context()
                      y_orig = probs[0]
                  elif Tag("get_pred", "victim") in self.victim.TAGS:
                      self.victim.set_context(res["data"], None)
                      try:
                          preds = self.victim.get_pred([x_orig])
                      finally:
                          self.victim.clear_context()
                      y_orig = int(preds[0])
                  else:
                      raise RuntimeError("Invalid victim model")
              info = res["metrics"]
              info["Succeed"] = res["success"]
              if visualize:
                  if progress_bar:
                      visualizer(i + 1, x_orig, y_orig, x_adv, y_adv, info, tqdm_writer, self.tokenizer)
                  else:
                      visualizer(i + 1, x_orig, y_orig, x_adv, y_adv, info, sys.stdout.write, self.tokenizer)

              #list for tsv
              succeed_list.append(res["success"])
              num_queries_list.append(res["metrics"]["Victim Model Queries"])
              x_orig_list.append(x_orig)

              if res["success"]:
                x_adv_list.append(x_adv)
              else:
                x_adv_list.append("ATTACK_UNSUCCESSFUL")



          for kw, val in res["metrics"].items():
              if val is None:
                  continue

              if kw not in total_result_cnt:
                  total_result_cnt[kw] = 0
                  total_result[kw] = 0
              total_result_cnt[kw] += 1
              total_result[kw] += float(val)
      # End for

      summary = {}
      summary["Total Attacked Instances"] = total_inst
      summary["Successful Instances"] = success_inst
      summary["Attack Success Rate"] = success_inst / total_inst
      for kw in total_result_cnt.keys():
          if kw in ["Succeed"]:
              continue
          if kw in ["Query Exceeded"]:
              summary["Total " + kw] = total_result[kw]
          else:
              summary["Avg. " + kw] = total_result[kw] / total_result_cnt[kw]

      if visualize:
          result_visualizer(summary, sys.stdout.write)


      #saving tsv
      if tsv_file_path is not None:
        with open(tsv_file_path, 'w') as f:
          f.write('succeeded' + '\t' + 'num_queries' + '\t' + 'original_text' + '\t' + 'modified_text' + '\t'+ '\n') #header
          for success, num_queries, x_orig, x_adv in zip(succeed_list, num_queries_list, x_orig_list, x_adv_list):
            escaped_x_orig = x_orig.replace('\n', '\\n') #escaping newlines
            escaped_x_adv = x_adv.replace('\n', '\\n')
            f.write(str(success) + '\t' + str(num_queries) + '\t' + escaped_x_orig + '\t' + escaped_x_adv + '\t'+ '\n')

      return summary

# %% [markdown]
# ## (optional) Mounting Google Drive

# %% [markdown]
# Steps to use mounted google drive:
# 1. create a folder in your local google drive (e.g. `incrediblAE_public_release`)
# 2. download all directories from the download link (see [Download section above](https://colab.research.google.com/drive/1juHWIL44z8O3C5wDAE45vzlJgX51KI5D?authuser=3#scrollTo=eVVE2-64rKuS&line=3&uniqifier=1://)) and upload them to your google drive folder
# 3. create an empty subdirectory called `outputs` (`incredibleAE_public_release/outputs/`)
#
# At this point, your google drive folder should have 6 subdirectories (C19, FC, HN, PR2, RD, and outputs)
# 4. uncomment code below, replacing path_to_mounted_dir with path to your folder (e.g. `/content/drive/My Drive/incrediblAE_public_release`)

# %% [markdown]
# You can also comment out the !gdown command in Downloading section, so the notebook doesn't redownload data each time you run it.

# %% [markdown]
# ## Making custom attacker (token shuffler)

# %% [markdown]
# Here's an example of how to create a custom attack method.
# Your attacker will need to subclass `OpenAttack.attackers.ClassificationAttacker`
#
# (See also OpenAttack framework docs: https://openattack.readthedocs.io/en/latest/)

# %%
import nltk
from nltk.corpus import stopwords, wordnet

nltk.download('stopwords')

nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\selin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\selin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\selin\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# '''
# This example code shows how to design a customized attack model (that shuffles the tokens in the original sentence).
# Taken from https://github.com/thunlp/OpenAttack/blob/master/examples/custom_attacker.py
# '''

# class MyAttacker(OpenAttack.attackers.ClassificationAttacker):
#     @property
#     def TAGS(self):
#         # Returns tags to help OpenAttack check your parameters automatically
#         return {self.lang_tag, Tag("get_pred", "victim")}

#     def __init__(self, tokenizer=None, max_generations=10, population_size=20):
#         if tokenizer is None:
#             tokenizer = PunctTokenizer()
#         self.tokenizer = tokenizer
#         self.lang_tag = OpenAttack.utils.get_language([self.tokenizer])
#         self.stop_words = set(stopwords.words('english'))
#         self.max_generations = max_generations
#         self.population_size = population_size
#         self.homoglyphs = {
#             'a': ['а', 'ɑ', 'а'],
#             'e': ['е'],
#             'o': ['о', 'ο', 'о'],
#             'c': ['с', 'ϲ'],
#             'p': ['р'],
#             'x': ['х'],
#             'y': ['у'],
#             'i': ['і'],
#             'l': ['ⅼ']
#         }

#     def attack(self, victim, input_, goal):
#         original_tokens = self.tokenizer.tokenize(input_)
#         population = [self.mutate(original_tokens) for _ in range(self.population_size)]

#         for generation in range(self.max_generations):
#             scored_population = [(individual, self.evaluate_fitness(individual, original_tokens, victim, goal)) for individual in population]
#             population = [x[0] for x in sorted(scored_population, key=lambda x: x[1], reverse=True)]

#             for individual in population:
#                 x_new = self.tokenizer.detokenize(individual)
#                 y_new = victim.get_pred([x_new])
#                 if goal.check(x_new, y_new):
#                     return x_new

#             population = self.evolve_population(population, original_tokens, victim, goal)

#         best_candidate = max(population, key=lambda ind: self.evaluate_fitness(ind, original_tokens, victim, goal))
#         adversarial_text = self.tokenizer.detokenize(best_candidate)
#         prediction = victim.get_pred([adversarial_text])
#         if goal.check(adversarial_text, prediction):
#             return adversarial_text
#         return None

#     def evolve_population(self, population, original_tokens, victim, goal):
#         new_population = []
#         parent_candidates = sorted(population, key=lambda ind: self.evaluate_fitness(ind, original_tokens, victim, goal))[:len(population)//2]

#         while len(new_population) < len(population):
#             parent1, parent2 = random.sample(parent_candidates, 2)
#             child1, child2 = self.crossover(parent1, parent2)
#             new_population.append(self.mutate(child1))
#             if len(new_population) < len(population):
#                 new_population.append(self.mutate(child2))

#         return new_population
    
#     def mutate(self, tokens, mutation_rate=0.1):
#         mutated_tokens = []
#         for token in tokens:
#             if random.random() < mutation_rate:
#                 mutation_type = random.choice(["swap", "split"])  # Choose mutation type
#                 if mutation_type == "swap":
#                     mutated_tokens.append(self.swap(token))
#                 elif mutation_type == "split":
#                     mutated_tokens.append(self.split_word(token))
#             else:
#                 mutated_tokens.append(token)
#         return mutated_tokens


#     def split_word(self, token):
#         if isinstance(token, tuple):
#             word = token[0]
#         else:
#             word = token

#         if len(word) > 1:
#             split_index = random.randint(1, len(word) - 1)
#             first_part = word[:split_index]
#             second_part = word[split_index:]
#             if isinstance(token, tuple):
#                 return (first_part + ' ' + second_part, token[1])
#             else:
#                 return first_part + ' ' + second_part
#         else:
#             return token


#     def evaluate_fitness(self, individual, original_tokens, victim, goal):
#         changes = sum(1 if orig != mod else 0 for orig, mod in zip(original_tokens, individual))
#         extra_tokens = len(individual) - len(original_tokens) 

#         adversarial_text = self.tokenizer.detokenize(individual)
#         prediction = victim.get_pred([adversarial_text])

#         if goal.check(adversarial_text, prediction):
#             fitness_score = -(changes + extra_tokens)
#         else:
#             fitness_score = -1000 - changes - extra_tokens

#         return fitness_score


#     def crossover(self, parent1, parent2):
#         possible_points = [i for i, token in enumerate(parent1) if ' ' not in token]
#         if not possible_points:
#             point = random.randint(1, len(parent1) - 1)
#         else:
#             point = random.choice(possible_points)

#         child1 = parent1[:point] + parent2[point:]
#         child2 = parent2[:point] + parent1[point:]
#         return child1, child2
    
#     def extra_bonus_for_splits(self, individual):
#         return sum(1 for token in individual if ' ' in token)  # Example bonus for each split
    
#     def select_parents(self, population, fitness_scores):
#         weighted_population = [(individual, score + extra_bonus_for_splits(individual)) for individual, score in zip(population, fitness_scores)]
#         sorted_population = sorted(weighted_population, key=lambda x: x[1], reverse=True)
#         return [x[0] for x in sorted_population[:len(population) // 2]]  # Select the top half


#     def is_better(self, individual1, individual2, original_tokens):
#         changes1 = sum(1 for orig, mod in zip(original_tokens, individual1) if orig != mod)
#         changes2 = sum(1 for orig, mod in zip(original_tokens, individual2) if orig != mod)

#         if changes1 < changes2:
#             return True
#         return False

#     def swap(self, token):
#       if isinstance(token, tuple):
#           word = token[0]
#       else:
#           word = token

#       modified_word = ''.join([random.choice(self.homoglyphs[char]) if char in self.homoglyphs else char for char in word])

#       if isinstance(token, tuple):
#           return (modified_word, token[1])
#       else:
#           return modified_word

# %%
class MyAttacker(OpenAttack.attackers.ClassificationAttacker):
    @property
    def TAGS(self):
        # Returns tags to help OpenAttack check your parameters automatically
        return {self.lang_tag, Tag("get_pred", "victim")}

    def __init__(self, tokenizer=None, max_generations=10, population_size=20):
        if tokenizer is None:
            tokenizer = PunctTokenizer()
        self.tokenizer = tokenizer
        self.lang_tag = OpenAttack.utils.get_language([self.tokenizer])
        self.stop_words = set(stopwords.words('english'))
        self.max_generations = max_generations
        self.population_size = population_size
        self.homoglyphs = {
            'a': ['а', 'ɑ', 'а'],
            'e': ['е'],
            'o': ['о', 'ο', 'о'],
            'c': ['с', 'ϲ'],
            'p': ['р'],
            'x': ['х'],
            'y': ['у'],
            'i': ['і'],
            'l': ['ⅼ']
        }

    def attack(self, victim, input_, goal):
        original_tokens = self.tokenizer.tokenize(input_)
        population = [self.mutate(original_tokens) for _ in range(self.population_size)]

        for generation in range(self.max_generations):
            scored_population = [(individual, self.evaluate_fitness(individual, original_tokens, victim, goal)) for individual in population]
            population = [x[0] for x in sorted(scored_population, key=lambda x: x[1], reverse=True)]

            for individual in population:
                x_new = self.tokenizer.detokenize(individual)
                y_new = victim.get_pred([x_new])
                if goal.check(x_new, y_new):
                    return x_new

            population = self.evolve_population(population, original_tokens, victim, goal)

        best_candidate = max(population, key=lambda ind: self.evaluate_fitness(ind, original_tokens, victim, goal))
        adversarial_text = self.tokenizer.detokenize(best_candidate)
        prediction = victim.get_pred([adversarial_text])
        if goal.check(adversarial_text, prediction):
            return adversarial_text
        return None

    def evolve_population(self, population, original_tokens, victim, goal):
        new_population = []
        parent_candidates = sorted(population, key=lambda ind: self.evaluate_fitness(ind, original_tokens, victim, goal))[:len(population)//2]

        while len(new_population) < len(population):
            parent1, parent2 = random.sample(parent_candidates, 2)
            child1, child2 = self.crossover(parent1, parent2)
            new_population.append(self.mutate(child1))
            if len(new_population) < len(population):
                new_population.append(self.mutate(child2))

        return new_population
    
    def mutate(self, tokens, mutation_rate=0.1):
        mutated_tokens = []
        for token in tokens:
            if random.random() < mutation_rate:
                mutation_type = random.choice(["swap", "split"])  # Choose mutation type
                if mutation_type == "swap":
                    mutated_tokens.append(self.swap(token))
                elif mutation_type == "split":
                    mutated_tokens.append(self.split_word(token))
            else:
                mutated_tokens.append(token)
        return mutated_tokens


    def split_word(self, token):
        if isinstance(token, tuple):
            word = token[0]
        else:
            word = token
        
        if len(word) > 3:
            if word[0] in 'ai':
                split_index = 1
            elif word[-1] in 'ai':
                split_index = len(word) - 1
            else:
                split_index = random.randint(2, len(word) - 2)
            first_part = word[:split_index]
            second_part = word[split_index:]
            if isinstance(token, tuple):
                return (first_part + ' ' + second_part, token[1])
            else:
                return first_part + ' ' + second_part
        else:
            return token



    def evaluate_fitness(self, individual, original_tokens, victim, goal):
        changes = sum(1 if orig != mod else 0 for orig, mod in zip(original_tokens, individual))
        extra_tokens = len(individual) - len(original_tokens) 

        adversarial_text = self.tokenizer.detokenize(individual)
        prediction = victim.get_pred([adversarial_text])

        if goal.check(adversarial_text, prediction):
            fitness_score = -(changes + extra_tokens)
        else:
            fitness_score = -1000 - changes - extra_tokens

        return fitness_score


    def crossover(self, parent1, parent2):
        possible_points = [i for i, token in enumerate(parent1) if ' ' not in token]
        if not possible_points:
            point = random.randint(1, len(parent1) - 1)
        else:
            point = random.choice(possible_points)

        child1 = parent1[:point] + parent2[point:]
        child2 = parent2[:point] + parent1[point:]
        return child1, child2


    def swap(self, token):
      if isinstance(token, tuple):
          word = token[0]
      else:
          word = token

      modified_word = ''.join([random.choice(self.homoglyphs[char]) if char in self.homoglyphs else char for char in word])

      if isinstance(token, tuple):
          return (modified_word, token[1])
      else:
          return modified_word

# %%
# '''
# This example code shows how to design a customized attack model (that shuffles the tokens in the original sentence).
# Taken from https://github.com/thunlp/OpenAttack/blob/master/examples/custom_attacker.py
# '''

# class MyAttacker(OpenAttack.attackers.ClassificationAttacker):
#     @property
#     def TAGS(self):
#         # Returns tags to help OpenAttack check your parameters automatically
#         return {self.lang_tag, Tag("get_pred", "victim")}

#     def __init__(self, tokenizer=None, max_generations=10, population_size=20):
#         if tokenizer is None:
#             tokenizer = PunctTokenizer()
#         self.tokenizer = tokenizer
#         self.lang_tag = OpenAttack.utils.get_language([self.tokenizer])
#         self.stop_words = set(stopwords.words('english'))
#         self.max_generations = max_generations
#         self.population_size = population_size
#         self.homoglyphs = {
#             'a': ['а', 'ɑ', 'а'],
#             'e': ['е'],
#             'o': ['о', 'ο', 'о'],
#             'c': ['с', 'ϲ'],
#             'p': ['р'],
#             'x': ['х'],
#             'y': ['у'],
#             'i': ['і'],
#             'l': ['ⅼ']
#         }
#         self.unicode_spaces = [
#             "\u0020",  # Regular space
#             "\u00A0",  # No-break space
#             "\u2002",  # En space
#             "\u2003",  # Em space
#             "\u2009",  # Thin space
#             "\u200A",  # Hair space
#             "\u202F",  # Narrow no-break space
#             "\u2060",  # Word joiner
#             "\u200B"   # Zero width space (may not be visible)
#         ]

#     def attack(self, victim, input_, goal):
#         original_tokens = self.tokenizer.tokenize(input_)
#         population = [self.mutate(original_tokens) for _ in range(self.population_size)]

#         for generation in range(self.max_generations):
#             scored_population = [(individual, self.evaluate_fitness(individual, original_tokens, victim, goal)) for individual in population]
#             population = [x[0] for x in sorted(scored_population, key=lambda x: x[1], reverse=True)]

#             for individual in population:
#                 x_new = self.tokenizer.detokenize(individual)
#                 y_new = victim.get_pred([x_new])
#                 if goal.check(x_new, y_new):
#                     return x_new

#             population = self.evolve_population(population, original_tokens, victim, goal)

#         best_candidate = max(population, key=lambda ind: self.evaluate_fitness(ind, original_tokens, victim, goal))
#         adversarial_text = self.tokenizer.detokenize(best_candidate)
#         prediction = victim.get_pred([adversarial_text])
#         if goal.check(adversarial_text, prediction):
#             return adversarial_text
#         return None

#     def evolve_population(self, population, original_tokens, victim, goal):
#         new_population = []

#         def tournament_selection(pop, k=3):
#             """ Select the best individual among `k` randomly chosen individuals from `pop`. """
#             selected = random.sample(pop, k)
#             best = max(selected, key=lambda ind: self.evaluate_fitness(ind, original_tokens, victim, goal))
#             return best

#         while len(new_population) < len(population):
#             parent1 = tournament_selection(population)
#             parent2 = tournament_selection(population)
#             child1, child2 = self.crossover(parent1, parent2)
#             new_population.append(self.mutate(child1))
#             if len(new_population) < len(population):
#                 new_population.append(self.mutate(child2))

#         return new_population

    
#     def mutate(self, tokens, mutation_rate=0.1):
#         mutated_tokens = []
#         for token in tokens:
#             if random.random() < mutation_rate:
#                 mutation_type = random.choice(["swap", "split"])
#                 if mutation_type == "swap":
#                     mutated_tokens.append(self.swap(token))
#                 elif mutation_type == "split":
#                     mutated_tokens.append(self.split_word(token))
#             else:
#                 mutated_tokens.append(token)
#         return mutated_tokens


#     def split_word(self, token):
#         if isinstance(token, tuple):
#             word = token[0]
#         else:
#             word = token

#         if len(word) > 1:
#             split_index = random.randint(1, len(word) - 1)
#             chosen_space = random.choice(self.unicode_spaces)
#             first_part = word[:split_index]
#             second_part = word[split_index:]
#             if isinstance(token, tuple):
#                 return (first_part + chosen_space + second_part, token[1])
#             else:
#                 return first_part + chosen_space + second_part
#         else:
#             return token



#     def evaluate_fitness(self, individual, original_tokens, victim, goal):
#         changes = sum(1 if orig != mod else 0 for orig, mod in zip(original_tokens, individual))
#         extra_tokens = len(individual) - len(original_tokens) 

#         adversarial_text = self.tokenizer.detokenize(individual)
#         prediction = victim.get_pred([adversarial_text])

#         if goal.check(adversarial_text, prediction):
#             fitness_score = -(changes + extra_tokens)
#         else:
#             fitness_score = -1000 - changes - extra_tokens

#         return fitness_score


#     def crossover(self, parent1, parent2):
#         possible_points = [i for i, token in enumerate(parent1) if ' ' not in token]
#         if not possible_points:
#             point = random.randint(1, len(parent1) - 1)
#         else:
#             point = random.choice(possible_points)

#         child1 = parent1[:point] + parent2[point:]
#         child2 = parent2[:point] + parent1[point:]
#         return child1, child2


#     def is_better(self, individual1, individual2, original_tokens, victim, goal):
#         adversarial_text1 = self.tokenizer.detokenize(individual1)
#         adversarial_text2 = self.tokenizer.detokenize(individual2)
        
#         prediction1 = victim.get_pred([adversarial_text1])
#         prediction2 = victim.get_pred([adversarial_text2])
        
#         goal_achieved1 = goal.check(adversarial_text1, prediction1)
#         goal_achieved2 = goal.check(adversarial_text2, prediction2)
        
#         changes1 = sum(1 for orig, mod in zip(original_tokens, individual1) if orig != mod)
#         changes2 = sum(1 for orig, mod in zip(original_tokens, individual2) if orig != mod)
        
#         if goal_achieved1 and not goal_achieved2:
#             return True
#         elif not goal_achieved1 and goal_achieved2:
#             return False
#         else:
#             return changes1 < changes2


#     def swap(self, token):
#       if isinstance(token, tuple):
#           word = token[0]
#       else:
#           word = token

#       modified_word = ''.join([random.choice(self.homoglyphs[char]) if char in self.homoglyphs else char for char in word])

#       if isinstance(token, tuple):
#           return (modified_word, token[1])
#       else:
#           return modified_word

# %%
# from transformers import BertModel, BertTokenizer
# from sklearn.metrics.pairwise import cosine_similarity
# import torch

# class MyAttacker(OpenAttack.attackers.ClassificationAttacker):
#     @property
#     def TAGS(self):
#         # Returns tags to help OpenAttack check your parameters automatically
#         return {self.lang_tag, Tag("get_pred", "victim")}

#     def __init__(self, tokenizer=None, max_generations=10, population_size=20):
#         if tokenizer is None:
#             tokenizer = PunctTokenizer()
#         self.tokenizer = tokenizer
#         self.lang_tag = OpenAttack.utils.get_language([self.tokenizer])
#         self.stop_words = set(stopwords.words('english'))
#         self.max_generations = max_generations
#         self.population_size = population_size
#         self.homoglyphs = {
#             'a': ['а', 'ɑ', 'а'],
#             'e': ['е'],
#             'o': ['о', 'ο', 'о'],
#             'c': ['с', 'ϲ'],
#             'p': ['р'],
#             'x': ['х'],
#             'y': ['у'],
#             'i': ['і'],
#             'l': ['ⅼ']
#         }
#         self.unicode_spaces = [
#             "\u0020",  # Regular space
#             "\u00A0",  # No-break space
#             "\u2002",  # En space
#             "\u2003",  # Em space
#             "\u2009",  # Thin space
#             "\u200A",  # Hair space
#             "\u202F",  # Narrow no-break space
#             "\u2060",  # Word joiner
#             "\u200B"   # Zero width space (may not be visible)
#         ]
#         self.bert_tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
#         self.bert_model = BertModel.from_pretrained('bert-base-uncased')
#         self.bert_model.eval()  # Set model to evaluation mode


#     def attack(self, victim, input_, goal):
#         original_tokens = self.tokenizer.tokenize(input_)
#         population = [self.mutate(original_tokens) for _ in range(self.population_size)]

#         for generation in range(self.max_generations):
#             scored_population = [(individual, self.evaluate_fitness(individual, original_tokens, victim, goal)) for individual in population]
#             population = [x[0] for x in sorted(scored_population, key=lambda x: x[1], reverse=True)]

#             for individual in population:
#                 x_new = self.tokenizer.detokenize(individual)
#                 y_new = victim.get_pred([x_new])
#                 if goal.check(x_new, y_new):
#                     return x_new

#             population = self.evolve_population(population, original_tokens, victim, goal)

#         best_candidate = max(population, key=lambda ind: self.evaluate_fitness(ind, original_tokens, victim, goal))
#         adversarial_text = self.tokenizer.detokenize(best_candidate)
#         prediction = victim.get_pred([adversarial_text])
#         if goal.check(adversarial_text, prediction):
#             return adversarial_text
#         return None

#     def evolve_population(self, population, original_tokens, victim, goal):
#         new_population = []

#         def tournament_selection(pop, k=3):
#             """ Select the best individual among `k` randomly chosen individuals from `pop`. """
#             selected = random.sample(pop, k)
#             best = max(selected, key=lambda ind: self.evaluate_fitness(ind, original_tokens, victim, goal))
#             return best

#         while len(new_population) < len(population):
#             parent1 = tournament_selection(population)
#             parent2 = tournament_selection(population)
#             child1, child2 = self.crossover(parent1, parent2)
#             new_population.append(self.mutate(child1))
#             if len(new_population) < len(population):
#                 new_population.append(self.mutate(child2))

#         return new_population
    
#     def mutate(self, tokens, mutation_rate=0.1):
#         mutated_tokens = []
#         for token in tokens:
#             if random.random() < mutation_rate:
#                 mutation_type = random.choice(["swap", "split"])
#                 if mutation_type == "swap":
#                     mutated_tokens.append(self.swap(token))
#                 elif mutation_type == "split":
#                     mutated_tokens.append(self.split_word(token))
#             else:
#                 mutated_tokens.append(token)
#         return mutated_tokens


#     def split_word(self, token):
#         if isinstance(token, tuple):
#             word = token[0]
#         else:
#             word = token

#         if len(word) > 1:
#             split_index = random.randint(1, len(word) - 1)
#             chosen_space = random.choice(self.unicode_spaces)
#             first_part = word[:split_index]
#             second_part = word[split_index:]
#             if isinstance(token, tuple):
#                 return (first_part + chosen_space + second_part, token[1])
#             else:
#                 return first_part + chosen_space + second_part
#         else:
#             return token

#     def get_embedding(self, text):
#         # Encode text using BERT tokenizer
#         inputs = self.bert_tokenizer(text, return_tensors='pt', padding=True, truncation=True, max_length=512)
#         # Get output from BERT model
#         with torch.no_grad():  # No need to calculate gradients
#             outputs = self.bert_model(**inputs)
#         # Extract the embeddings from the last hidden state
#         embeddings = outputs.last_hidden_state.mean(dim=1).squeeze().numpy()
#         return embeddings


#     def evaluate_fitness(self, individual, original_tokens, victim, goal):
#         adversarial_text = self.tokenizer.detokenize(individual)
#         prediction = victim.get_pred([adversarial_text])

#         # Check if the goal is achieved
#         if goal.check(adversarial_text, prediction):
#             fitness_score = 100  # High score for achieving the goal
#         else:
#             fitness_score = 0
        
#         # Embedding of the original and adversarial texts
#         original_emb = self.get_embedding(self.tokenizer.detokenize(original_tokens))
#         adversarial_emb = self.get_embedding(adversarial_text)
        
#         # Cosine similarity to measure semantic preservation
#         semantic_score = cosine_similarity([original_emb], [adversarial_emb])[0][0]
        
#         # Penalize the number of changes
#         changes = sum(1 if orig != mod else 0 for orig, mod in zip(original_tokens, individual))
        
#         # Combine scores: prioritize goal achievement, then maximize semantic similarity and minimize changes
#         fitness_score += semantic_score * 10 - changes  # Adjust weights as necessary

#         return fitness_score



#     def crossover(self, parent1, parent2):
#         possible_points = [i for i, token in enumerate(parent1) if ' ' not in token]
#         if not possible_points:
#             point = random.randint(1, len(parent1) - 1)
#         else:
#             point = random.choice(possible_points)

#         child1 = parent1[:point] + parent2[point:]
#         child2 = parent2[:point] + parent1[point:]
#         return child1, child2


#     def is_better(self, individual1, individual2, original_tokens, victim, goal):
#         adversarial_text1 = self.tokenizer.detokenize(individual1)
#         adversarial_text2 = self.tokenizer.detokenize(individual2)
        
#         prediction1 = victim.get_pred([adversarial_text1])
#         prediction2 = victim.get_pred([adversarial_text2])
        
#         goal_achieved1 = goal.check(adversarial_text1, prediction1)
#         goal_achieved2 = goal.check(adversarial_text2, prediction2)
        
#         changes1 = sum(1 for orig, mod in zip(original_tokens, individual1) if orig != mod)
#         changes2 = sum(1 for orig, mod in zip(original_tokens, individual2) if orig != mod)
        
#         if goal_achieved1 and not goal_achieved2:
#             return True
#         elif not goal_achieved1 and goal_achieved2:
#             return False
#         else:
#             return changes1 < changes2


#     def swap(self, token):
#       if isinstance(token, tuple):
#           word = token[0]
#       else:
#           word = token

#       modified_word = ''.join([random.choice(self.homoglyphs[char]) if char in self.homoglyphs else char for char in word])

#       if isinstance(token, tuple):
#           return (modified_word, token[1])
#       else:
#           return modified_word

# %% [markdown]
# ## Testing your attack

# %% [markdown]
# The code below will test MyAttacker (above) on the victim classifier, compute BODEGA score, and output results to /content/BODEGA/outputs.
#
# WARNING: files in default output directory (/content/BODGEa/outputs) do not persist after you disconnect from the colab runtime session. To keep them, you can either:
#
# 1. download them manually or
# 2. set `out_dir` to a mounted Google Drive directory (will automatically save files to your google drive)

# %% [markdown]
# ### Choose task + victim classifier

# %%
# determinism
random.seed(10)
torch.manual_seed(10)
np.random.seed(0)

# Change these variables to what you want
task = 'RD' # PR2, HN, FC, RD, C19
victim_model = 'surprise' # BERT or BiLSTM or surprise
using_custom_attacker = False # change to False if you want to test out OpenAttack's pre-implemented attackers (e.g. BERTattack)
attack = 'BERTAttack' # if using custom attack, this name can be whatever you want. If using pre-implemented attack, set to name of attacker ('BERTattack')

# misc variables - no need to change
targeted = False # this shared task evaluates performance in an untargeted scenario
visualize_adv_examples = True # prints adversarial samples as they are generated, showing the difference between original
using_first_n_samples = False # used when you want to evaluate on a subset of the full eval set.
first_n_samples = 20

# %% [markdown]
# ### Run to evaluate attacker

# %%
if using_mounted_drive:
    data_path =  pathlib.Path(f"{path_to_mounted_folder}/{task}")
    model_path = pathlib.Path(f"{path_to_mounted_folder}/{task}/{victim_model}-512.pth")
    out_dir = pathlib.Path(f"{path_to_mounted_folder}/outputs")

else:
  data_path =  pathlib.Path(f"path-to-your-folder/incrediblAE_public_release/{task}")
  model_path = pathlib.Path(f"path-to-your-folder/incrediblAE_public_release/{task}/{victim_model}-512.pth")
  out_dir = pathlib.Path(f"path-to-your-folder/outputs/{task}/{victim_model}")

if out_dir:
    out_dir.mkdir(parents=True, exist_ok=True)



RESULTS_FILE_NAME = 'results_' + task + '_' + str(targeted) + '_' + attack + '_' + victim_model + '.txt' #stores BODEGA metrics
SUBMISSION_FILE_NAME = 'submission_' + task + '_' + str(targeted) + '_' + attack + '_' + victim_model + '.tsv' #stores original and modified text, to be submitted to shared task organizers

results_path = out_dir / RESULTS_FILE_NAME if out_dir else None
submission_path = out_dir / SUBMISSION_FILE_NAME if out_dir else None

if out_dir:
    if (out_dir / RESULTS_FILE_NAME).exists():
      print(f"Existing results file found. This script will overwrite previous file: {str(results_path)}")
    if submission_path.exists():
      print(f"Existing submission file found. This script will overwrite previous file: {str(submission_path)}")




# Prepare task data
with_pairs = (task == 'FC' or task == 'C19')

# Choose device
print("Setting up the device...")

using_TF = (attack in ['TextFooler', 'BAE'])
if using_TF:
    # Disable GPU usage by TF to avoid memory conflicts
    import tensorflow as tf

    tf.config.set_visible_devices(devices=[], device_type='GPU')

if torch.cuda.is_available():
    print('using GPU')
    victim_device = torch.device("cuda")
    attacker_device = torch.device("cuda")
else:
    victim_device = torch.device("cpu")
    attacker_device = torch.device('cpu')

# Prepare victim
print("Loading up victim model...")
if victim_model == 'BERT':
    victim = VictimCache(model_path, VictimBERT(model_path, task, victim_device))
    readfromfile_generator = BERT_readfromfile_generator
elif victim_model == 'BiLSTM':
    victim = VictimCache(model_path, VictimBiLSTM(model_path, task, victim_device))
    readfromfile_generator = BERT_readfromfile_generator
elif victim_model == 'surprise':
    victim = VictimCache(model_path, VictimRoBERTa(model_path, task, victim_device))
    readfromfile_generator = roberta_readfromfile_generator

# Load data
print("Loading data...")
test_dataset = Dataset.from_generator(readfromfile_generator,
                                      gen_kwargs={'subset': 'attack', 'dir': data_path, 'trim_text': True,
                                                  'with_pairs': with_pairs})
if not with_pairs:
    dataset = test_dataset.map(dataset_mapping)
    dataset = dataset.remove_columns(["text"])
else:
    dataset = test_dataset.map(dataset_mapping_pairs)
    dataset = dataset.remove_columns(["text1", "text2"])

dataset = dataset.remove_columns(["fake"])

# Filter data
if using_first_n_samples:
  dataset = dataset.select(range(first_n_samples))

if targeted:
    dataset = [inst for inst in dataset if inst["y"] == 1 and victim.get_pred([inst["x"]])[0] == inst["y"]]

print("Subset size: " + str(len(dataset)))

# Prepare attack
print("Setting up the attacker...")

# Necessary to bypass the outdated SSL certifiacte on the OpenAttack servers
with no_ssl_verify():
  if using_custom_attacker:
    attacker = MyAttacker()
  else:
    filter_words = OpenAttack.attack_assist.filter_words.get_default_filter_words('english') + [SEPARATOR_CHAR]
    if attack == 'PWWS':
        attacker = OpenAttack.attackers.PWWSAttacker(token_unk=UNK_TEXT, lang='english', filter_words=filter_words)
    elif attack == 'SCPN':
        os.environ["TOKENIZERS_PARALLELISM"] = "false"
        attacker = OpenAttack.attackers.SCPNAttacker(device=attacker_device)
    elif attack == 'TextFooler':
        attacker = OpenAttack.attackers.TextFoolerAttacker(token_unk=UNK_TEXT, lang='english',
                                                           filter_words=filter_words)
    elif attack == 'DeepWordBug':
        attacker = OpenAttack.attackers.DeepWordBugAttacker(token_unk=UNK_TEXT)
    elif attack == 'VIPER':
        attacker = OpenAttack.attackers.VIPERAttacker()
    elif attack == 'GAN':
        attacker = OpenAttack.attackers.GANAttacker()
    elif attack == 'Genetic':
        attacker = OpenAttack.attackers.GeneticAttacker(lang='english', filter_words=filter_words)
    elif attack == 'PSO':
        attacker = OpenAttack.attackers.PSOAttacker(lang='english', filter_words=filter_words)
    elif attack == 'BERTattack':
        attacker = OpenAttack.attackers.BERTAttacker(filter_words=filter_words, use_bpe=False, device=attacker_device)
    elif attack == 'BAE':
        attacker = OpenAttack.attackers.BAEAttacker(device=attacker_device, filter_words=filter_words)
    else:
        attacker = None

# Run the attack
print("Evaluating the attack...")
RAW_FILE_NAME = 'raw_' + task + '_' + str(targeted) + '_' + attack + '_' + victim_model + '.tsv'
raw_path = out_dir / RAW_FILE_NAME if out_dir else None

with no_ssl_verify():
    scorer = BODEGAScore(victim_device, task, align_sentences=True, semantic_scorer="BLEURT", raw_path = raw_path)
    attack_eval = BodegaAttackEval(attacker, victim, language='english', metrics=[
        scorer  # , OpenAttack.metric.EditDistance()
    ])
    start = time.time()
    summary = attack_eval.eval_and_save_tsv(dataset, visualize=visualize_adv_examples, progress_bar=False, tsv_file_path = submission_path)
    end = time.time()
attack_time = end - start
attacker = None

# Remove unused stuff
victim.finalise()
del victim
gc.collect()
torch.cuda.empty_cache()
if "TOKENIZERS_PARALLELISM" in os.environ:
    del os.environ["TOKENIZERS_PARALLELISM"]

# Evaluate
start = time.time()
score_success, score_semantic, score_character, score_BODEGA= scorer.compute()
end = time.time()
evaluate_time = end - start

# Print results
print("Subset size: " + str(len(dataset)))
print("Success score: " + str(score_success))
print("Semantic score: " + str(score_semantic))
print("Character score: " + str(score_character))
print("BODEGA score: " + str(score_BODEGA))
print("Queries per example: " + str(summary['Avg. Victim Model Queries']))
print("Total attack time: " + str(attack_time))
print("Time per example: " + str((attack_time) / len(dataset)))
print("Total evaluation time: " + str(evaluate_time))

if out_dir:
  with open(results_path, 'w') as f:
      f.write("Subset size: " + str(len(dataset)) + '\n')
      f.write("Success score: " + str(score_success) + '\n')
      f.write("Semantic score: " + str(score_semantic) + '\n')
      f.write("Character score: " + str(score_character) + '\n')
      f.write("BODEGA score: " + str(score_BODEGA) + '\n')
      f.write("Queries per example: " + str(summary['Avg. Victim Model Queries']) + '\n')
      f.write("Total attack time: " + str(end - start) + '\n')
      f.write("Time per example: " + str((end - start) / len(dataset)) + '\n')
      f.write("Total evaluation time: " + str(evaluate_time) + '\n')

  print('-')
  print('Bodega metrics saved to', results_path)
  print('Submission file saved to', submission_path)
# Out:
# Setting up the device...
# using GPU
# Loading up victim model...
# Victim caching: file found, loading...
# Loading data...
# Subset size: 415
# Setting up the attacker...
# Evaluating the attack...
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BleurtSPTokenizer'.
# The class this function is called from is 'BertTokenizer'.
# Exception when evaluate data {'x': "Reports: #CharlieHebdo suspects killed http://t.co/rsl4203bcQ\nDamn, this is like a movie RT @HuffingtonPost Reports: #CharlieHebdo suspects killed http://t.co/zCuZD1cure\n“@HuffingtonPost: Reports: #CharlieHebdo suspects killed http://t.co/mWCSjh3CkH” superb simultaneous response by the French tactics unit.\n@HuffingtonPost great news! No trial, no taxpayer money spent to support them.\n@HuffingtonPost Good news !!! Alah Akbar !!\n@HuffingtonPost damnit!!! That's what those fuckers wanted!! Now they will be hailed as martyrs....\n@HuffingtonPost Can you confirm the reports that those suspects were killed by French police?\n@HuffingtonPost good.\n@HuffingtonPost That's a good start\n@HuffingtonPost They got Netanyahu's Mossad agents? GOOD. Don't fuck with the French -- they invented the guillotine!\n@HuffingtonPost Chance lost to bring them to big trial and exposure to the world. A pitty they were not caught alive! Now they are martirs!\n@HuffingtonPost Some good news!\n@HuffingtonPost  http://t.co/SiJ5OGTxir un artículo objetivo que entiende y explica las causas y consecuencias del doloroso ataque en París", 'y': 1}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': "Reports the two #CharlieHebdo suspects declared they want to 'die as martyrs' #ParisShooting http://t.co/f30TSVt1yN http://t.co/Zhe1p4fBeU\n@Independent make it slow and painful ....\n@Independent  Protector of Islam gets a slam. [;D [:P [:D    http://t.co/792W1s0mjt\n@Independent  Diaries of an assassin. Smile because you are a Muslim. :) :D :D :O :Q    http://t.co/AXhC17ab7v\n@Independent Taking life is wrong full stop. Let them rot, perhaps even give them a handcuffed audience with the families of those killed.\n@Independent  Sheik parrot is not wrong. Islam is the wrong.   http://t.co/iKGvT0GJMd\n@Independent So make them live as murderers.\n@Independent  The law of do not say the truth.    http://t.co/7JJe8mx2xp\n@Independent Bin Laden believers = Paris event believers about idiocy. They're not Muslim, they from Mossad's special unities.\n@Independent If you believe they're Muslim, then you have Don Quijote syndrome.\n@Independent stop calling them martyrs they're murderers.", 'y': 1}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': "My favourite picture so far. #JeSuisCharlie http://t.co/87m8PF4w05\n@iremuu @Jontybark thats getting right to the point\n“@iremuu: My favourite picture so far. #JeSuisCharlie http://t.co/bmxJoVv5Gc” 😂😂😂\n@iremuu mine as well\n@iremuu Congrats on your 250★ tweet! http://t.co/7SArGYOZXP\n@iremuu @joyvalencia It's a nice pic but it's at least 3 years old. Sentiment is still as fresh today though :)\n“@iremuu: My favourite picture so far. #JeSuisCharlie http://t.co/f3EyFwWiYo” this is awesome!\nThis needs to be RT'D 10K times @iremuu\n@iremuu @HallLenard  I 'get it' but rather graphic crude words.\n“@iremuu: My favourite picture so far. #JeSuisCharlie http://t.co/AMc6vcAxXC”\n“@iremuu: My favourite picture so far. #JeSuisCharlie http://t.co/KbCXRsmm0S” Simple and succinct 😄\n“@iremuu: My favourite picture so far. #JeSuisCharlie http://t.co/s0qU4ksmOx” HELL YEAH!!!!!!!!!!!\n@iremuu Congrats on your 1000★ tweet! http://t.co/DnkN43orJy\n@iremuu LOVE IT! @deaf_erin\nRT of @iremuu via @deaf_erin\n@iremuu @Nien_Nunb Yeah...that's a real winner. I didn't want to start off 2015 with all this bullshit. *cry facepalm*\n@iremuu @Nat_fried Why can't everyone get along nicely anymore🗼✌\n@iremuu Damn Staright/Ahuevo!!!!!!!!!!!!!\n@iremuu @BlueJaysLifer although I love this pic (it was my Facebook profile pic for a few months) has nothing to do with the Paris incident\n@BlueJaysLifer it does", 'y': 0}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': 'R.I.P. Ahmed Merabet, a French police officer, a Muslim, the first victim of #CharlieHebdo attack, http://t.co/bMzZgpXuL7 via @Ironyisfunny8\n@greenhousenyt @jaketapper @Ironyisfunny8 so sad\n@greenhousenyt @jaketapper @Ironyisfunny8 .... Cowardly shameful act of obscene hatred..Thoughts and prayers to this Police Officers family\n@greenhousenyt @MayaErgas @Ironyisfunny8 And what\'s the name of the second police officer who was killed?\n@greenhousenyt @Ironyisfunny8 Wow, makes this evil act even more abysmal\n#Sheepdog #tbl MT @greenhousenyt #RIPAhmedMerabet a French police officer, Muslim, 1st victim of #CharlieHebdo attack http://t.co/KsB4AXs7zD\n@greenhousenyt @barbarastarrcnn @Ironyisfunny8 So Sad!!!!Rip\n@greenhousenyt @Ironyisfunny8 ppl believe that those bloody Islamists murders were not aware that they were killing a Muslim Police officer\n@greenhousenyt @jaketapper @Ironyisfunny8 ironic that a Muslim killed a Muslim #riphero #BlueLivesMatter\n@rokul59 @greenhousenyt @Ironyisfunny8 Had they known would hated him even more.\n@greenhousenyt @_BekkyC_ @Ironyisfunny8 What irony.\n@RWarsin @greenhousenyt @Ironyisfunny8 hardliners see him as hypocrite, fallen almost subhuman, whereas cartoonists seen as dogs\n@_BekkyC_ @greenhousenyt @Ironyisfunny8 You lost me here Bekka\n@RWarsin @greenhousenyt @Ironyisfunny8 "Bosnian Imam attacked 7X for calling ISIS a \'perverted version of Islam\' http://t.co/MnSyFBuRDa\n@_BekkyC_ @greenhousenyt @Ironyisfunny8 Thanks I\'m a little tired .\n@RWarsin @greenhousenyt @Ironyisf', 'y': 1}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': "'Charlie Hebdo' editor killed in Paris terror attack built career on defiance http://t.co/T6VqPcerWe\n“@TIME: 'Charlie Hebdo' editor killed in Paris terror attack built career on defiance http://t.co/GY0AIlayOL”\n@TIME Terrorist attacks in Australia and Paris, links in a chain - #Russian_terror http://t.co/PrDJMdDTxy\n@TIME Hey man I'm sickened, cowardly hit and run god-dammed motherf*****s. Je suis Charlie, nous sommes Charlie, vive la France!\n#FreeSpeech #JeSuisCharlie “@TIME: 'Charlie Hebdo' editor killed in Paris terror attack built career on defiance http://t.co/pcJoAwJsLm”\n“@TIME: 'Charlie Hebdo' editor killed in Paris terror attack built career on defiance http://t.co/LwaBWMkgjt”@54Baker articles for extemp?\n@TIME - #jesuischarlie #charliehebdo - I am Charlie #vivalafrance - Rest in Peace heroic Journalists/Editor @charliehebdo\n@TIME Baby photo contest are involved, you voted offline publications Tweet thank you http://t.co/Cf3z3jOxyx\n@TIME  to protect free speech all media, TV, papers, magazines should print & show all the cartoons!!!!!!NOW!!!!\n@TIME http://t.co/yX8hvshsPW\n@cooper_alexa @TIME Thanks cooper!! 👍👍", 'y': 0}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': 'French radio @Europe1 says attackers on offices of Paris weekly ran out yelling "Allahu Akbar" #Charliehebdo\n@marcburleigh @Europe1 figures....when will France and the EU learn.\n@SottileStephen @marcburleigh @Europe1 Only after it\'s way too late and millions have to die to stamp out the savage muslims.\n@marcburleigh @michaeldickson @Europe1 How come they are telling the truth now? Waking up to Islam?  HAPPY NOW @ChTaubira ? Your protégés?\n@marcburleigh @michaeldickson @Europe1 ..Of course they were!..\n@marcburleigh @pragnik @Europe1 I am told #Obama brushing microphone to tell it has nothing to do with Islam.\n@SottileStephen  It is years since @MarkSteynOnline warned Europe. People called him names. Now people die.  @marcburleighIt @Europe1\n@marcburleigh @MumbaikiGirl @Europe1     Allahu Akbar :)\n@marcburleigh @michaeldickson @Europe1   Not lone wolves this time then. When will they learn?\n@marcburleigh @Europe1 @omalestafeito and that makes them muslims? I can shout that and im an atheist.\n@marcburleigh @BJPLucknowBJP @Europe1 All muslims are not terrorist but all terrorist are Muslims.', 'y': 1}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': '‘The death of faith in the West makes it harder for us to engage with Islam.\'  http://t.co/KI4UUnhFcy (Pic: Rex) http://t.co/HDARGUoTtS\n@Telegraph  #StopKillingInnocentPeople #FreePalestine #freeBurma #FreeSyria  #FreeKashmir http://t.co/ggBNiIa9fq\n@Telegraph Engage them with overwhelming firepower.\n@Telegraph It died for a reason.\n@Telegraph basically that is bollocks - plenty have faith. Most do not have a mediaeval mindset.\n@telegraph All religions are man made. They are political tools to control the ignorant masses!\n@JeanODwyer @Telegraph   amen to that. Thank god it did\n@Telegraph As did the people of Sodom & Gomorrah.\n@Telegraph maybe is not our lack of faith, maybe you were just not convinced enough\n@Telegraph blah, blah, blah.... You have no courage, no guts and don\'t understand what Islam is all about: conquer and submit!\n@Telegraph It\'s a shame Christianity is absolute horse shit, it really is.\n@Telegraph Atheism does not suggest a lack of morals, quite the opposite. All religion is man-made to force conformity in a tribal context\n@Telegraph Total bollocks again from Stanley Religion is dying for a reason We have grown up It\'s make believe deluded & dangerous nonsense\n@Telegraph Some peoples beliefs are so absurd though so this difficult "ENGAGEMENT" will probably remain so.\n@Telegraph Thankfully we\'re at the point where we can think for ourselves. Not to say we don\'t see the value of principles taught in bible\n@Telegraph The concept of religion - believing in a non-existent god - is utterly ridiculous. I can\'t believe people fall for it.\n@Telegraph liberal nonsense by Tim Stanley. 24 hrs after 12 people were killed by Muslim gunmen and you say secularism is the problem. Joker\n@deejayhome @Telegraph Agreed. Liberal nonsense from Stanley.\n@RealChangePak secular extremists? Examples please @Telegraph\n@Telegraph Me praying to my dog is no more or less credible than someone praying to Allah.\n@RealChangePak satire isn\'t extremism. it was a drawing not a beheading or bombing over', 'y': 0}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': "DEVELOPING: Women, children held in second Paris hostage situation; may be related to massacre http://t.co/F4K3C1lot7\n“@FoxNews: DEVELOPING: Women, children held in second Paris hostage situation; may be related to massacre http://t.co/DkLN07IKHI”\n@FoxNews FFS\n@FoxNews  the majority of Muslims have no desire to ostracize the cancer that is eating away at Islam... the world needs to do that\nRT @FoxNews: DEVELOPING: Women, children held in second Paris hostage situation; may be related to massacre http://t.co/N26Aw0Fnq7\n@FoxNews Christ. it's like i m living a nightmare and i can't woke up\n@FoxNews Such a peaceful religion.\n@FoxNews What a mess.\n@FoxNews May be. Can you people try to dissemble any more than  you do. It isn't Alleged. It is definite. Militant Islam is at War .with us.\n@FoxNews @Saints859 I know a qualified silent group of professionals who helped UBL to the after life that I'm sure would be happy to help.\n@FoxNews France is in turmoil. They have many hard days ahead of them\n@FoxNews Please not the children.\n@ChrisPV66 @FoxNews The Qu'Ran clearly states: No democracy. Only Islam. ALL of the MUSLIMS want this. THEY WILL NEVER REPUDIATE. nEVER.\n@FoxNews  Bunch of fkin cowards...leave our children alone!!\n@hollyammon @ChrisPV66 @FoxNews  Cowards\n@FoxNews and of course Obama will call this workplace violence\n@FoxNews some great news every morning thanks for keeping us informed and sexy ladies all day long\n@FoxNews A populace w/the right to arm themselves for self defense would doubtlessly have someone in that group to shoot those bastards dead\nRT @FoxNews: DEVELOPING: Women, children held in second Paris hostage situation; may be related to massacre http://t.co/Kq60lWieSx\n@FoxNews French now is dealing with the open border policy they had in the last few years with former colonized countries (Algeria).\n@FoxNews it's time", 'y': 0}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': 'Killing writers and journalists and cartoonists will not silence them but make their voices louder. #CharlieHebdo\n@JonnyGeller Inchaallah! Rip @Charlie_Hebdo_\n@JonnyGeller Not really, I bet you hear no criticism of Islam now. All the left wing hatred will be focused on Christians.\nFor sure RT @JonnyGeller: Killing writers and journalists and cartoonists will not silence them but make their voices louder. #CharlieHebdo\nI urge others to repost work done by those who have been killed & any material that extremists point to as justification. @JonnyGeller\nExactly: "@JonnyGeller: Killing writers and journalists and cartoonists will not silence them but make their voices louder. #CharlieHebdo”\n@JonnyGeller @JonLeeWriter Jonathan, Be Safe, we in America Love Your Words and Tweets!', 'y': 0}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': '→ http://t.co/Jz4Lrp0eZb 433 Charlie Hebdo shooting: World leaders condemn attack in Paris #CharlieHebdo Masked gunm… http://t.co/ULH3Vt3TG8\n@johnspatricc !This is a great atrocity ... God is the center of all religions .. All prophets is his messenger ....', 'y': 0}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': "#Banksy's take on #CharlieHebdo. #JeSuisCharlie #NousSommesCharlie http://t.co/f6Y07d9fJ1\n@juliamacfarlane http://t.co/zHekINcQjJ\nBanksy gets it right. “@juliamacfarlane: #Banksy's take on #CharlieHebdo. #JeSuisCharlie #NousSommesCharlie http://t.co/Y51AAQ6DRm”", 'y': 1}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': 'Brilliant #CharlieHebdo satirists did not attack #Islam, but poked fun @ #intolerance & #extremism of all kind inc #racism & #islamophobia.\n@bouckap @MsKristinKreuk I agree.\n@bouckap @MsKristinKreuk HAHAHA I\'m not sure if this post is meant to be satirical or not but... http://t.co/SevfEcSOGb\n@bouckap @priyanica they did attack Islam by attacking our beloved prophet saw. This gives fuel and manpower to extremists. it\'s a cycle\n@bouckap @IngridMattson Civilised world has a duty to unite in championing the satirical work cruelly interrupted today in France!\n@bouckap Should have poked fun at those who insult sensitivitys of 1.5 billion moslims, Christians, jews and others! Ce la vie!\n@bouckap @MsKristinKreuk Which these extremists can\'t and probably won\'t ever understand. Saddening. #CharlieHebdo\n@AndyDefinite @bouckap @IngridMattson  - Bombs and blockades that imprison, starve and murder millions in the ME made in "civilized" world.\n@AndyDefinite @bouckap @IngridMattson - It\'s the "civilized" Banksters who turn us against one another while they profit from war and debt.\n@bouckap @MsKristinKreuk #JeSuisCharlie tribute to the victims #CharlieHebdo   Long live #freedom of expression http://t.co/oOnm2t4WTR', 'y': 0}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': 'One can condemn the #CharlieHebdo killings, while conjointly condemning racism, xenophobia, and Islamophobia framed as harmless cartoons.\n@LeftSentThis brilliant! Absolutely.\n@LeftSentThis Islamophobia? #CharlieHebdo published cartoons satirising all the major religions not only Islam. How is that Islamophobia?\n@LeftSentThis Makes me wonder if the artists at #CharlieHebdo were really left wing in their politics.\n@LeftSentThis  The freedom of ideas being killed by offence is barbarism. The right to say whatever is universal, as is the right to argue.\n@LeftSentThis Why do you not comment on the fact Jews and Catholics were also a subject of their satire????.\n@LeftSentThis well said.\n@LeftSentThis You will go to jail if you deny the Holocaust in France. Freedom of Speech? No nude cartoons of Jews in #CharlieHebdo\n@forumeditor @LeftSentThis I think his point still stands though. it doesn\'t matter if all religions were subject to his satire.\n@LeftSentThis @FoxyJazzabelle This really isn\'t hard concept2parse unless UR a racist,xenophobic asshole who also traffics in Islamophobia.\n@LeftSentThis @riamichelle http://t.co/ga8H6968Kr\nWord “@LeftSentThis: 1 can condemn  #CharlieHebdo killings and also condemn racism, xenophobia & Islamophobia framed as harmless cartoons”\n@Eliota_Sapolu @LeftSentThis Perfectly put!\n@Eliota_Sapolu @LeftSentThis why condemn satire? Everything should be fair game.\n@RhodaDavids @Eliota_Sapolu @LeftSentThis freedom of thought & speech for all.The harsh backlash,saying Islam is this or that...you cant 1/2\n@RhodaDavids @Eliota_Sapolu @LeftSentThis 2/2 condemn an entire worldwide religion based on the actions of a few.All faiths have extremists.\n@LeftSentThis @hahellyer those cartoons are not "racism, xenophobia, and Islamophobia"  it\'s free speech!!! (as the ones about the Pope....)\n@LeftSentThis @pfc_fez by adding your disclaimer that the cartoons are improper you are supporting the view of', 'y': 0}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': 'AFP reporting that two people have been killed in hostage situation in grocery store in eastern Paris. Unconfirmed. #ParisShooting\n@NevMab @raulgaab Denied: https://t.co/weqqb4lyW8\n@pjarmengou @NevMab Police on the ground told to reporters.', 'y': 1}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': "BREAKING: Three gunmen involved in attack on Charlie Hebdo magazine, French Interior Minister Bernard Cazeneuve says. http://t.co/ak9mTVfJdR\n@cnni the Islamic leaders should do something about the image of islam by speaking out against the terrorists\n@cnni expel muslims from european soil and destroy all the mosques.\n@cnni it's not the religion.  But how the people  interpret the writings and that's what causes them to do bad things.\n@cnni terrorism needs concerted efforts from every citizen to fight it,religion is going beyond boundaries if it can cause terror attacks", 'y': 1}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': 'Tina Fey: “We cannot back down on free speech in any way” http://t.co/jJGxtXRPi7 #CharlieHebdo\n@TIME  #CharlieHebdo  Back down for what & for who? http://t.co/XRjEIcMC2d\n@TIME #CharlieHebdo  #InsultIsNotFreeSpeech #ProvocationIsNotFreeSpeech #SpeakResponsiblyDrawResponsibly #RespectIslam #RespectForMuslims\n@TIME 66 retweets and 42 favorites.\n@TIME free speech and democracy mean respectful not insulting or disrespectful\n@TIME #CharlieHebdo  When you insult and provoke people, you are responsible for the consequences. #ProvocationIsNotFreeSpeech #RespectIslam\n@TIME Tell it Tina. And don\'t back down. #CharlieHebdo\n@aquil123 @TIME Nope. Free Speech means Free Speech. #CharlieHebdo\nThen don\'t be surprised about Korea-“@TIME: Tina Fey: “We cannot back down on free speech in any way” http://t.co/5SCB5YX1mo #CharlieHebdo”\n@TIME #Charlie #INKnLIGHT\n@TIME Tina Fey is such an important and respected journalist.\n@TIME As a teacher and because these terrorists attended our schools we need to learn our children respect/love for others + for themselves\n@TIME No, but we can use appropriate discretion and, when it comes to satire, respect.\nInteresting >>“@TIME: Tina Fey: “We cannot back down on free speech in any way” http://t.co/GvsQ1fYVPD #CharlieHebdo”\n“@TIME: Tina Fey: “We cannot back down on free speech in any way” http://t.co/2DAjSDvoXk #CharlieHebdo" @carochicken\nTina Fey is 100% right! ..But where was she   & her Hollywood friends when @HillaryClinton put filmmaker in jail? @jfh38d @TIME @nicejumble\nWhere was #TinaFey & @ChloeGMoretz , when @HillaryClinton jailed film maker?..#CharlieHebdo @jfh38d @TIME @nicejumble http://', 'y': 0}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': "#CharlieHebdo update: Suspects in contact with police, say they want to die as martyrs http://t.co/7wSzrByj2n\n@BostonGlobe as long as they do that alone, be my guests!\n@BostonGlobe let's make their dreams come true", 'y': 1}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': 'Video posted online appears to show gunmen fleeing after attack on #CharlieHebdo  magazine office in Paris http://t.co/bEri7HY51w\n@BBCBreaking Thanks for editing out the first part of the video! #CharlieHebdo\n“@BBCBreaking: Video posted online appears to show gunmen fleeing after attack on #CharlieHebdo magazine in Paris http://t.co/rfYDE1jt3c”\n@bbcbreaking At least 12 killed in shooting at office of French satirical: http://t.co/dTrEfTWyLp #paris Charlie Hebdo\n@BBCBreaking @CalvinSwine905 The Killing Act is cheap theatrics and Def n0t G0d in the highest ...Just Boys with the Toys\n@SteamersBaby @BBCBreaking  🚶Dude, inappropriate to say, "Just Boys with Toys." Louts with clout more appropriate.🙇 #Paris #CharieHebdo\n@CalvinSwine905 @BBCBreaking where did they get the Clouts? Ah yes-High Tech Weapons? Hmmm???\n@CalvinSwine905 @BBCBreaking Theater of Death-bad Scene All over the World-Need love here on Mother Earth Now\n@SteamersBaby @BBCBreaking  AK-47s\n@BBCBreaking: don\'t think any right thinking individual needs to understand Islam/Moslems. So much evil,  know some people might not like dc', 'y': 0}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': 'Charlie Hebdo to continue publishing in the wake of the attack http://t.co/6bMvM3wgkL http://t.co/dBBG4L40Kx\n@WSJeurope @WSJ Good for them, so proud, I wish we had journalist we could be proud of\n@WSJeurope @WSJ that\'s wrong. religion should not be made fun of\n@WSJeurope @WSJ LES RELIGIONS DOIVENT ÊTRE UNIS 🙏🙏 http://t.co/ZZDKRKhRg0\n@WSJeurope @WSJ Post office’s around the world should deliver2ISIS first class. #IamCharlie\n@WSJeurope @WSJ JE SUIS CHARLIE.\n@612Flint @WSJeurope @WSJ TRY TO FIND A CLUE, YOU BELONG IN THE 7TH  CENTURY.\n@WSJeurope @WSJ I still don\'t get that joke\n@WSJeurope @WSJ And get some added security if anything you publish might offend a Muslim.\n@hollyammon @WSJeurope @WSJ anyone who disagrees with you belongs to the 7th century.\n@bguarino58 @WSJeurope @WSJ warm words for these fighters of liberty with pensil ! thx\n@WSJeurope @WSJ  resilient bunch\n@hollyammon can\'t even tolerate difference of opinion and teach others freedom of speech stro imposing your thinking on others\n@hollyammon stop imposing your views on others\nWhat bravery looks like. “@WSJeurope: Charlie Hebdo to continue publishing... http://t.co/W1a6ASpgcB http://t.co/O1vdxORqXj”\n“@WSJeurope: Charlie Hebdo to continue publishing in the wake of the attack." THEY MUST.\n“@WSJeurope: Charlie Hebdo to continue publishing in the wake of the attack http://t.co/YlD5IjJTZh http://t.co/TYfrctuZ76”\n“@WSJeurope: Charlie Hebdo to continue publishing in the wake of the attack http://t.co/LOZlc53Hlf http://t.co/', 'y': 0}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': 'BREAKING: Suspects in Charlie Hebdo massacre have been killed after a standoff with French law enforcement officials http://t.co/XZo6ISivf0\n@Salon OMG! You got something right! You guys should take the rest of the day off before you screw something else up! Quick! Go home!\n@Salon all done. With both sites. Died and forces did great job.\n.@Salon Good, they deserved it.', 'y': 1}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': 'The Earth without Art is just \'Eh\'. #streetart #JeSuisCharlie http://t.co/72XpFM2kOn\n@charliesaidthat @inthecompanyof Unfortunately, for some murderers, the "earth" without "art" leaves just "He". Which is the problem.\n@charliesaidthat Your name is all over Twitter.\n@GaryDayEllison It feels like it.\n@charliesaidthat I actually saw your status saying #JeSuisCharlie before the news and wondered why you\'re saying you\'re Charlie in French...\n@charliesaidthat You said it.\n“@charliesaidthat: The Earth without Art is just \'Eh\'. #streetart #JeSuisCharlie http://t.co/qvFOam85RJ” love this\n@charliesaidthat Rightly said! All the art lovers out there would surely agree with it. #BeInteresting #Streetart\n@JesseCEEEE @QuayeJulian @charliesaidthat ...so pay for art as you would expect to pay for food. Artists need to eat too.\n@DeanPHanley @QuayeJulian @charliesaidthat so I do ?!\n@JesseCEEEE @QuayeJulian @charliesaidthat So many people pirate nowdays, and call it "sharing".\n@DeanPHanley @QuayeJulian @charliesaidthat yes they do\n@DeanPHanley @QuayeJulian @charliesaidthat that\'s why u shouldn\'t put shit up that u don\'t want to share\n@JesseCEEEE @QuayeJulian @charliesaidthat But if you put it in a box and don\'t let anyone see it ever, you never sell anything.\n@JesseCEEEE @QuayeJulian @charliesaidthat A shop puts it\'s products in a window, as advertising, not as an invitation to steal.\n@JesseCEEEE @QuayeJulian @charliesaidthat If someone breaks the glass to get it, that person is a thief, not a customer.\n@DeanPHanley @QuayeJulian @charliesaidthat yes that\'s why u have stuff u put on the net to be over exposed and collections u display n sell?\n@JesseCEEEE @QuayeJul', 'y': 0}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': 'I see humans but no humanity. #LiberteDExpression #JeSuisCharlie  #charliehebdo http://t.co/6jRiKDHTSr\n@VigilanteArtist @Madonna @ladygaga @KingBrush @MiamiHerald  @DRJAMESCABOT @sallybell26 @mileycyrus @FloydMayweather http://t.co/6jRiKDHTSr\n@VigilanteArtist como estas,Ale?\n@Subaquei Muy bien gracias a full con la rehabilitacion el 21 me operan la izq GRACIASS!!\n@VigilanteArtist Me alegro mucho!!! Todo saldrá bien!! YEAHHHH!! Carños a #Sally y a #Milano\n@VigilanteArtist @MarinaBush90 👏👏👏', 'y': 0}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': 'Michelle Stanistreet, general secretary of the National Union of Journalists (UK) on the #CharlieHebdo attack: http://t.co/L0uUdPmswx\n@guardian prayers for France! USA SUPPORTS FREEDOM OF THE PRESS!\n@guardian @tigeriza \'...without threats, intimidation, and ...\' wonder ...how about how @FreeBarrett_ Brown, @FreeJeremyNet  Hammond treated\n#religionofpeace "@guardian: Gral. secretary of the National Union of Journalists (UK) on the #CharlieHebdo attack: http://t.co/z8aB6N2Z82”\n@guardian @dwwatchnews now if the corporations of the world agree, we would not need we would really have #pressfreedom from censorship.\n@guardian Freedom Freedom Freedom, Never Never Never STAND DOWN . VIVA LA FRANCE.\n@guardian So let\'s see these cartoons on tomorrow\'s front pages. Surely. Surely ?\n@guardian MOST RELIGIOUS ORGANISATIONS LIKE TO SILENCE THEIR CRITICS TRY #METHODISTCONF OR #CHURCHOFENGLAND SADLY THESE TWATS JUST USE GUNS\n@guardian\n#echr Freedom of Expression belongs to the world “@guardian National Union of Journalists (UK) #CharlieHebdo attack: http://t.co/pALXM3QLUN”\n@guardian Republish the cartoons #CharlieHebdo\n@guardian At least 12 killed in shooting at office of French satirical: http://t.co/dTrEfTWyLp #paris Charlie Hebdo\n@guardian supporters of free speech and liberty in Europe have been victimised as right wing "racists" of late unfortunately . #pegida\n@guardian plz retweets HAPY NEW YEAR GUYS SHARE PASS IT ON. http://t.co/IUhfDfx1wk  http://t.co/TfdW20lKcK … http://t.co/MLSW8rmeVV\nMT @guardian: Michelle Stanistreet, general sec of the National Union of Journalists (UK) on #CharlieHebdo attack: http://t.co/rNYCO5Eaxc\n“@guardian: Hear, hear! Ms', 'y': 0}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': 'The German newspaper Berliner Kurier printed a new #Mohammed cartoon on today\'s front page. #JeSuisCharlie http://t.co/rpNHS7BmiL\n@matthew_hunt @MaggieJordanACN | But it\'s only funny if one believes  #Mohammed did the killing.\n@matthew_hunt @smaccaroo  Translation "our freedom you can not murder"\n@matthew_hunt @yagbebi I don\'t think they should \'buy\' into this...  Take the "higher ground..."\n@yagbebi @matthew_hunt Nothing...   But this appears "tit for tat" and paints all Muslims the same, which is absolutely not true!!!\n@yagbebi @matthew_hunt Likely to stir up more hate, and resentment...  Not less!\n@yagbebi @matthew_hunt God knows the world require more understanding of each other, and respect for our differences.\n@matthew_hunt @MaggieJordanACN racists.\n@yagbebi @SebWrites @matthew_hunt suddenly every douchebag is an expert on freedom of zpeach\n@matthew_hunt @RedNationRising As a Christian in Christian Country I kno Jesus & God, undrstnd Atheist, Agnostic & Saints. WTH is #Mohammed?\n@matthew_hunt @RedNationRising unfollow me please-I\'m not part of "the revolution" who needs to spread manure.\n@matthew_hunt @RedNationRising they should have included some bacon.\n@matthew_hunt So when exactly was Mohammed born anyway?\n.@SebWrites @yagbebi @matthew_hunt check out @TarekFatah who\'s Muslim  & been trying 2 educate us abt these crazy ones; also Dr. Jasser\n@matthew_hunt @RedNationRising Excellent. All publications should do the same.\n@matthew_hunt @markc2902 Great free speech\n@SebWrites @yagbebi @matthew_hunt and saying nothing, just ignore? Provocation is the basis of debate\n@SebWrites @yagbebi @matthew_hunt Read the Quran - then come back and', 'y': 0}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': 'Gathering in support of #CharlieHebdo at 6pm in Trafalgar Square, London. Please share widely https://t.co/4a2f2NONyR http://t.co/4dbswcQsKS\n@becksunyer @mediaguardian Who funded/armed/trained gunmen? https://t.co/iPBkLwhQk8 … >Jeffrey Epstein also in CFR+Trilateral Commission<\n@becksunyer @indiaknight why th hell on earth must he be supported??for creating choas???\n@becksunyer @indiaknight I cannot be there but will be in thought. I have been horrendously shocked by this.\nMT “@becksunyer: Gathering in support of #CharlieHebdo at 6pm in Trafalgar Square, London. https://t.co/GJDGGe5EEa http://t.co/3LlprAuAyu”\n@becksunyer @EmmaFrancesCarr I can see Islamist conspiracy theorists re-spacing that slogan and finding a "secret crusade".\n@becksunyer Link closed if you’re not a friend, I think - can you tweet an open one?\n@becksunyer @MrGolly Thanks 4 cartoonists killed Cabu Wolinski Tignous & Charb  + 8 defender of freedom of expression http://t.co/FhpUzOTuQB\n@becksunyer Hi I work for @BBC_WHYS. Are you attending this vigil?\n@EmmaWilson1 @BBC_WHYS I am. Follow me and I\'ll DM my phone number!\n@becksunyer @MrsMillsST Le monde libre est Charlie. A bas les fascistes Islamiques.\n@becksunyer @mediaguardian\n@becksunyer  let\'s stand together & hold hands & fight for freedom & justice\n@becksunyer @aw_avril gutted wish I had known\n@becksunyer  link isn\'t working for me\n@becksunyer @stuartmwrites Good ideaCharlie Hebdo is such a great mag...', 'y': 0}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': "Did this in a rush for @SkyNews before latest #CharlieHebdo media maelstrom http://t.co/EFgnTIwouk\n@MartinRowson @SkyNews\n@MartinRowson I know everything you've done and said has been your own response but thanks from this old pencil pusher for saying it all\n@MartinRowson @SkyNews vive tout les cartoonists\n@MartinRowson  #Kobane defender of #civilsociety v/sadden by loosing our supporter  #CharlieHebdo #ParisShooting http://t.co/a0NBTIBAqL\n@MartinRowson @PeterTatchell @SkyNews clowns to us, but sadly millions of extremist idolize such facist terrorists\n@iamstoner @MartinRowson @SkyNews HaHaHa L{}Ve it !\n@MartinRowson @SkyNews  🌟🌟🌟🌟🌎🌍🌏🎨✏✒📰👌👍👏👏👏👏🌊💙🌊💙🌊💙🌊⛵🌊🚢🌊💙  #NousSommesTousCharlie #weareallcharlie\n@MartinRowson @SkyNews if terrorists killed every one, would they have to do an honest job, or go on the dole?\n@wheneverisit1 @SkyNews Good point. But if everyone was dead, who would they work for?\n@MartinRowson @SkyNews i was thinking  about their ' real world survival' skills. bet they cant even do their own laundry.\n@MartinRowson @SkyNews Like the style Mr Rowson... V Beano :))", 'y': 0}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': 'In the last hour, all 3 Islamic terrorists at both hostage sites, Port Vincennes and Dammartin, have been killed by French police.\n@Mike_Fabricant The police did a fantastic job on this.\n@TonyCalder3 How many Jewish what?\n@Mike_Fabricant The woman Hayat Boumeddienne appear to have escaped. Bloody \'ell...\n@Mike_Fabricant @John_M_Ward Thank you Lumiose Police!\n@Mike_Fabricant Really? It looks like that was the CRS, not the police.\n.@mrmjcable Is not the CRS, along with the Police Nationale and the Gendarmerie, a branch of the French police service?\n@Mike_Fabricant Yes. My point is that it is a specialized unit and should not be used in general terms as "the police"\n.@mrmjcable Ummmm. Slightly pedantic n\'est pas?   #analretentive\n"@lambandflag99 "N\'est-ce pas"   if you want pedantry!" <  That\'s not pedantry, that\'s a helpful reminder of my schoolboy French. Thanks!', 'y': 1}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': "Armed French Police At Trocadero In Paris http://t.co/ZpJZ7M5ns3\n@SkyNews Interior Ministry says this is a false alarm\n“@SkyNews: Armed French Police At Trocadero In Paris http://t.co/fuQHUcvEWC” no way. This is so tragic\n@SkyNews false alarm\n@SkyNews really good reporting Sky.  Thanks.\n@SkyNews it's a false alarm\nRT @SkyNews Armed French Police At Trocadero In Paris http://t.co/VZLW7NpRST …\n@skynews If this was in the UK the pair would either be banged up or shot dead long ago\n@SkyNews just said this could be distractions for something more major, exactly what i was thinking\n@SkyNews where are the french army special forces shouldnt they be involved by now?\n@SkyNews whatever next in beautiful Paris? More hostages,killing & now the Tower? It's getting worse. So sad, such a lovely place #desperate\n@SkyNews Wondering if they targeted the printing place on purpose? Is it linked to #CharlieHebdo #prayingforfrance ❤️\n@SkyNews another attack ?\n@thehugheslady false alarm\n@CalebHowe @SkyNews Unreal to me that they have to specify that these police are armed\n@Ste_F1 phew. They can barely cope right now\n@thehugheslady everyone is on high alert as expected, awful news day\n@Ste_F1 too terrible. Bad start to year and I don't expect it to improve.\n@thehugheslady it's the lunatic copycats I'm worried about\n@Ste_F1 loads of them will have a pop for sure...", 'y': 1}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': 'Paris Mayor Anne Hidalgo rushing to scene of hostage situation in Porte de Vincennes area of Paris: http://t.co/qB4b5cKvPg\n@cnni सबै भन्छन म मा हिम्मत  http://t.co/a6I60AssKZ\n@cnni where are the Arab countries condemning these attacks and fighting against terrorist?  Why is it only America doing everything?? @CNN\n@cnni Do the police really need politicians arriving on the scene and meddling\n@cnni http://t.co/gB4ImNnfs7 #JeSuisCharlie #CharlieHebdo #islamisnotterrorism #IslamIsNotTheProblem http://t.co/AWtcTrbc3P\n@cnni Muslims are terrorist , Islam is a trash religion - its a sick cult ..\n@cnni why would anyone convert to this trash religion who was founded by a sick man Mohammed who had sex with a child ??\n“@cnni: Paris Mayor Anne Hidalgo rushing to scene of hostage situation in Porte de Vincennes area of Paris: http://t.co/xh2g9JSXxj”\n@cnni @cnnbrk who cares! bring in Massad they will end this. Then as mayor sign the decree to deport ALL islam (moooslims) to the arabdesert\n@miami305fan @cnni @CNN Arabs r the cause. U can bet Massad is working to end this fast.\n@CompositeStick @cnni @cnnbrk The French are pussys when it comes to this crap.Massad will end the store standoff.\n@cnni @cnnbrk funny to see French on their knees by some muslims 😝😝\n@cnni Not in my country. No governor\n@cnni Not possible in my country Nigeria.\n@cnni @tolu_dr: And Jonathan sat "holed-up" in Abuja.\n@ajulu23 @cnni For once he never visited a trouble spot, just like POTUS or Kerry will into Iraq or Afghanistan. Utterly disappointed\n@cnni @cnnbrk what the hell us gonna do there?', 'y': 0}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': "'It's a massacre. There are dead!' employee of Charlie Hebdo tells French media outlet before call disconnects http://t.co/Q27XnP3AS3\n@RT_com moderates.... Great job France the rest of the world should wake up!\n@RT_com that's what happens.\n@RT_com What a shame. Where was the armed security to deal with 3 assailants?\n@RT_com What's up with the security at that moment?\n@RT_com too many sad things happening all around the globe", 'y': 0}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': "We're deeply shocked and saddened by the despicable violence in Paris today. Freedom of expression is fundamental. #JeSuisCharlie\nIndeed. Vive la Paris. MT  “@Shakespeare_Co: We're deeply shocked and saddened by the despicable violence in Paris today. #JeSuisCharlie”", 'y': 0}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# Exception when evaluate data {'x': 'If these fuckers in Paris didn\'t have hostages if AC130 them bitches.\n@ProSyndicate That mission from MW3 though <3\nI know it\'s not possible for those questioning this comment 😑\n@ProSyndicate they might have a javelin though to take it down?\n@ProSyndicate hahaha fuckem\n@ProSyndicate *Tactical Nuke inbound*\n@ProSyndicate #avaitionnerd AC130 would be wrong approach. The gunship is useless in undercover situations. K-9 unit is what you meant 😂😂👍\n@ProSyndicate but yeah agree man. Shit that\'s happened is so saddening :,(\n@nathanjrix @ProSyndicate A javelin is ground to ground.\n@luke19959 @ProSyndicate no, he meat AC130, as he said\n@Sniper_Brandoh @ProSyndicate no it\'s not it takes out aircraft lol\n@nathanjrix @ProSyndicate Its an Anti Tank weapon. Lol\n@Sniper_Brandoh @nathanjrix @ProSyndicate It is anti tank that\'s why it goes up then down to the tank are rhere is less arourlm\n@bharmston_bh @nathanjrix @ProSyndicate My best friend was in the military, I kinda have a clue what equipment they use.\n@Anonymoustachio Learn to spell, GG\n@luke19959 *meant. Well you didn\'t pick up on when he said "didn\'t have hostages if AC130.." So stfu\n@Anonymoustachio learn to understand wht he was saying properly GG "KID"\n@luke19959 learn to understand what I was saying, and stop using GG, you sound like a fanboy.\n@luke19959 LEARN TO SPELL "WHAT", KID. GG\n@Anonymoustachio Wow I missed out the "A" which I just couldn\'t be asked to put in. Bloody hell brah stop crying! Hahaa\n@luke19959 You talk shit for something I did then you go ahead and do it but all of a sudden it\'s justified.\n@Anonymoustachio shhhhhh kid, don\'t cry! Haha\n@luke19959 I\'m', 'y': 0}
# Traceback (most recent call last):
#   File "c:\Users\selin\miniconda3\Lib\site-packages\OpenAttack\attack_eval\utils.py", line 10, in attack_process
#     adversarial_sample = attacker(victim, data)
#                          ^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not callable
# ...
# then this # tshirt is for you support #     |
# JeSuisCharlie # CharlieHebdo buy it now     |
# http :// t . co / XKBSwygvDG                |
#                                             |
# Sample: 408 ===================================================================
# Label: 1 (97.86%) --> Failed!               |
#                                             |
# Two people died Friday after a gunfire in a | Running Time:            0.0010023
# Kosher grocery store in Porte de Vincennes  | Query Exceeded:          no
# in eastern Paris : http :// t . co /        | Victim Model Queries:    0
# wNaWo8sCwR @ MarketWatch False information  | BODEGA Score:            (later)
# , no dead people at the kacher grocery #    | Succeed:                 no
# CharlieHebdo                                |
#                                             |
# Sample: 409 ===================================================================
# Label: 0 (99.67%) --> Failed!               |
#                                             |
# Brilliant . # JeSuisCharlie via @ lectrr    |
# http :// t . co / CSe2EN1Fxg @ XopheRobin @ |
# lectrr Brilliant ! “@ XopheRobin :          |
# Brilliant . # JeSuisCharlie via @ lectrr    |
# http :// t . co / 6KpyuurnrE ” OUTstanding  |
# !! @ XopheRobin @ lectrr A complete GIF     |
# guide to Muslims Denouncing terrorism .     |
# http :// t . co / s9rGMNFzda @ XopheRobin @ |
# lectrr Et il vas encore plus , le devenir ! |
# Ce crayon vas devenir la pire arme contre   | Running Time:            0.0009980
# le sunnisme fascisme . @ XopheRobin @       | Query Exceeded:          no
# ElectreIsMore @ lectrr plus il devient      | Victim Model Queries:    0
# petit aussi et jusqu ’ à disparaitre , bof  | BODEGA Score:            (later)
# y a mieux ... “@ XopheRobin : Brilliant . # | Succeed:                 no
# JeSuisCharlie via @ lectrr http :// t . co  |
# / UR9WN5tN8a ” @ RainHeart69 @              |
# ElectreIsMore @ lectrr Il ressemble à       |
# Astérix le Gaulois , non ? Petit , droit ,  |
# aiguisé & résistant . Très bien ce cartoon  |
# . :) “@ XopheRobin : Brilliant . #          |
# JeSuisCharlie via @ lectrr http :// t . co  |
# / 16fwbENQSQ ” “@ XopheRobin : Brilliant .  |
# # JeSuisCharlie via @ lectrr http :// t .   |
# co / xmX1M0zUeQ ”                           |
#                                             |
# Sample: 410 ===================================================================
# Label: 0 (99.60%) --> Failed!               |
#                                             |
# Cartoons don ' t insult me or my religion   |
# the brutal murder of innocent people does # |
# JeSuisCharlie http :// t . co / hxnMFztgom  |
# @ HumzaYousaf I love you , Humza . I mean , |
# more than usual . @ HumzaYousaf Bravo . @   |
# HumzaYousaf you are a voice of reason and   |
# tolerance in a world that seems to have     |
# gone completely mad , thank you #           |
# JeSuisCharlie @ JournoStephen @ HumzaYousaf |
# + 1 . @ HumzaYousaf u can condemn the       |
# attack without supporting racist cartoons . |
# @ HumzaYousaf Well said @ 19Panther90 @     |
# HumzaYousaf What racist cartoon ? @         |
# stukinnear http :// t . co / sxiMukzEaj @   |
# stukinnear http :// t . co / io4gEoHJsj @   |
# 19Panther90 What ' s racist about it ? @    |
# HumzaYousaf @ coyjim Sorry Humjob ... you   |
# are the ENEMY !!! @ stukinnear one is a     | Running Time:            0
# drawing of a black minister as a monkey ,   | Query Exceeded:          no
# other is saying the kidnapped girls in      | Victim Model Queries:    0
# Nigeria want to keep their babies ( cont )  | BODEGA Score:            (later)
# @ stukinnear for child benefits @           | Succeed:                 no
# 19Panther90 Whilst the first might be       |
# borderline - why is the second racist ? @   |
# stukinnear its the stereotype that brown /  |
# black ppl r lazy , live off the state etc @ |
# HumzaYousaf L ' Amérique se tient avec la   |
# France . # JeSuisCharlie @ HumzaYousaf      |
# Congrats on your 500 ★ tweet ! http :// t . |
# co / G6smjJfPeQ @ HumzaYousaf well ,        |
# cartoons can be pretty hurtful , as can     |
# speech : i ' m a woman , i only need to     |
# look at some of misogynist stuff from       |
# 18thcent @ HumzaYousaf so i sympathise with |
# people who disagree with it : but killing   |
# for it ' s stupid . Need sane religion ,    |
# not insane , or hurt yourself @ 19Panther90 |
# @ HumzaYousaf Charlie was a racist bigot .  |
# You can support freedom of speech and be    |
# against murder without supporting a racist  |
# .                                           |
#                                             |
# Sample: 411 ===================================================================
# Label: 0 (99.58%) --> Failed!               |
#                                             |
# Muslims get judged every day because of all |
# these terrorist attacks . They are VICTIMS  |
# , not supporters . # CharlieHebdo http ://  |
# t . co / LbXhLcnby7 @ tobeymonster at the   |
# end of the day , religion is often just an  |
# excuse for human behaviour . @ tobeymonster |
# just a FYI http :// t . co / T6AsjLVCvM @   |
# tobeymonster BILL GATES ETHICAL ??????? 1 . |
# @ tobeymonster thank you for defending      |
# muslim people inspite of all the fake news  |
# arround , the world needs more people like  |
# you 2 . @ tobeymonster you may dont know me |
# but i just want to say thank you for your   |
# bravery to say your opinion and not afraid  |
# of wht ppl say @ tobeymonster WRONG .       |
# RELIGION CREATES IMMORALITY AND CRIME . IT  |
# MAKES OTHERWISE SANE MEN INTO MURDERERS . @ |
# tobeymonster THAT ' S NOT AN ARGUMENT . USE | Running Time:            0.0012879
# YOUR BRAIN . @ tobeymonster LET ' S HEAR AN | Query Exceeded:          no
# ARGUMENT INSTEAD OF AN AD HOMINEM ATTACK .  | Victim Model Queries:    0
# DO YOU HAVE ONE ? @ tobeymonster RELIGION   | BODEGA Score:            (later)
# SWITCHES OFF CRITICAL THINKING & CAN LEAD   | Succeed:                 no
# TO VIOLENCE . THIS IS WHAT HAS HAPPENED     |
# HERE . ( PATRIOTISM CAN DO THE SAME ) @     |
# tobeymonster you ' re the best @            |
# OscarLacrosse @ tobeymonster wow you ' re   |
# trash @ tobeymonster yessss .... @          |
# tobeymonster @ yasminR_xx Chart forgot the  |
# good jews and the bad jews as well as other |
# races and sexual orientations . we ' re all |
# good and bad @ oscaralcivar @ tobeymonster  |
# yeah . However , jews aren ' t really       |
# involved with this situation and the        |
# Christians example was used as they are @   |
# oscaralcivar @ tobeymonster ... portrayed   |
# as innocent and the '' superior religion '' |
# @ imgagashusband @ tobeymonster the truth   |
# must be conveyed , @ majesticvxbez @        |
# tobeymonster THAT ' S NOT AN ARGUMENT . USE |
# YOUR MIND . @ OscarLacrosse @ tobeymonster  |
# exactly                                     |
#                                             |
# Sample: 412 ===================================================================
# Label: 1 (75.00%) --> Failed!               |
#                                             |
# 3 suspects ( 34 , 32 ,& 18 yrs old ) have   | Running Time:            0.0009990
# been identified in the # CharlieHebdo       | Query Exceeded:          no
# attack & are from Reims ( Paris suburb ). 2 | Victim Model Queries:    0
# of them are brothers @ KATUNews say it with | BODEGA Score:            (later)
# me ... TERRORISTS .. Can you ?... suspects  | Succeed:                 no
# my ASS                                      |
#                                             |
# Sample: 413 ===================================================================
# Label: 0 (99.63%) --> Failed!               |
#                                             |
# " Love is stronger than hate ": #           |
# CharlieHebdo cover after Molotov cocktail   |
# attack on its offices in 2011 http :// t .  |
# co / 0XTOpHNGjw @ mathieuvonrohr @          | Running Time:            0.0009990
# houdamzioudet @ Abo_El_Darawesh @ SA_AlZawi | Query Exceeded:          no
# @ mathieuvonrohr @ Abo_El_Darawesh Never    | Victim Model Queries:    0
# been fan of @ Charlie_Hebdo_ sickened by    | BODEGA Score:            (later)
# thugs who are highjacking my religion every | Succeed:                 no
# day @ mathieuvonrohr This # picture has #   |
# nothing to do with # love Mathieu , this is |
# very # ugly , # filthy & # disgusting #     |
# provocation ... @ Temidor @ Temidor @       |
# mathieuvonrohr It ' s satire and very apt . |
#                                             |
# Sample: 414 ===================================================================
# Label: 1 (99.14%) --> Failed!               |
#                                             |
# # BREAKING Gunman has taken hostages at     | Running Time:            0
# kosher supermarket in eastern Paris , local | Query Exceeded:          no
# official says http :// t . co / 7tGdSv4fr8  | Victim Model Queries:    0
# @ USATODAY anything but what ' s happening  | BODEGA Score:            (later)
# here , as the stealth jihad continues in    | Succeed:                 no
# the # USATODAY                              |
#                                             |
# Sample: 415 ===================================================================
# Label: 1 (96.14%) --> Failed!               |
#                                             |
# Gunmen at # CharlieHebdo ' s Paris HQ       | Running Time:            0
# shouted they had " avenged the prophet ",   | Query Exceeded:          no
# reports say http :// t . co / MQz906TgPm    | Victim Model Queries:    0
# http :// t . co / Q6WaU7JJvx @              | BODEGA Score:            (later)
# LJPmcLoughlin of course they did & how      | Succeed:                 no
# convenient " someone " only heard that .    |
#                                             |
# +=========================================+
# |                 Summary                 |
# +=========================================+
# | Total Attacked Instances:  | 415        |
# | Successful Instances:      | 0          |
# | Attack Success Rate:       | 0          |
# | Avg. Running Time:         | 0.00063039 |
# | Total Query Exceeded:      | 0          |
# | Avg. Victim Model Queries: | 0          |
# | Avg. BODEGA Score:         | nan        |
# +=========================================+
# Victim caching: saving...
# Aligning sentences...
# Using model LAMBO_213-UD_English-EWT
# Computing semantic score...
# Computing BODEGA score...
# Subset size: 415
# Success score: 0.0
# Semantic score: nan
# Character score: nan
# BODEGA score: 0.0
# Queries per example: 0.0
# Total attack time: 0.7902829647064209
# Time per example: 0.0019042963004973997
# Total evaluation time: 0.03686165809631348
# -
# Bodega metrics saved to C:\Users\selin\Documents\CheckThat\BODEGA\outputs\RD\surprise\results_RD_False_BERTAttack_surprise.txt
# Submission file saved to C:\Users\selin\Documents\CheckThat\BODEGA\outputs\RD\surprise\submission_RD_False_BERTAttack_surprise.tsv
# c:\Users\selin\miniconda3\Lib\site-packages\numpy\lib\function_base.py:520: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# c:\Users\selin\miniconda3\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# Your output should look like this.
# The custom attack has a very low BODEGA score, suggesting that the attack was not very successful (low success rate and low preservation of meaning).
#
# VictimBERT on PR2:
# ```
# Subset size: 416
# Success score: 0.1778846153846154
# Semantic score: 0.40792732766351186
# Character score: 0.3001644500157
# BODEGA score: 0.02308437726605881
# Queries per example: 2.1778846153846154
# Total attack time: 19.421820878982544
# Time per example: 0.04668706942063112
# Total evaluation time: 10.617336988449097
# ```

# %% [markdown]
# ## Submission Files

# %% [markdown]
# Whenever you run an attack on a dataset, a submission_task.tsv file will be saved to your outputs directory. At the end of the test phase, you will need to submit your final attack's submission files to the shared task organisers for evaluation (1 for each dataset * num_victim_classifiers).
#
# The submission file contains 4 pieces of information per attacked text:
# 1. was the attack successful
# 2. number of queries to victim model used to generate the adversarial sample
# 3. the original text
# 4. the adversarial text (or ATTACK_UNSUCCESSFUL if unsuccessful)

# %% [markdown]
# ## Final tips:
#
# ### Using a subset of eval dataset
# Testing your attack on the entire eval dataset can take a while. To speed things up, you can test on the first n samples of the dataset, by setting `using_first_n_samples` to `True`.
#
# ### Running pre-implemented attacks
#
# BODEGA supports a number of pre-existing attacks. Trying these might be useful if you want to:
# - compare your performance with existing methods (also reported in the [BODEGA preprint](https://arxiv.org/abs/2303.08032))
# - get inspiration from observing their substitutions
#
# To use an existing attack requires only two changes to the code above:
# 1. set `using_custom_attacker` to `False`
# 2. set `attack` to the name of a supported attack
# (`PWWS`, `SCPN`, `TextFooler`, `DeepWordBug`, `GAN`, `Genetic`, `PSO`, `BERTattack` or`BAE`)
#
# Note that using `BAE` or `TextFooler` will require you to install additional dependencies since they rely on tensorflow:
#
# - tensorflow >= 2.0.0
# - tensorflow_hub
#
# https://openattack.readthedocs.io/en/latest/quickstart/installation.html
